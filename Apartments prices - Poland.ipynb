# %% [markdown]
# ## Apartments prices in Poland

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
apartments = pd.read_csv("apartments_pl_2023_08.csv")
apartments.head()
# Out:
#                                  id      city          type  squareMeters  \
# 0  f8524536d4b09a0c8ccc0197ec9d7bde  szczecin  blockOfFlats         63.00
# 1  accbe77d4b360fea9735f138a50608dd  szczecin  blockOfFlats         36.00
# 2  8373aa373dbc3fe7ca3b7434166b8766  szczecin      tenement         73.02
# 3  0a68cd14c44ec5140143ece75d739535  szczecin      tenement         87.60
# 4  f66320e153c2441edc0fe293b54c8aeb  szczecin  blockOfFlats         66.00
#
#    rooms  floor  floorCount  buildYear   latitude  longitude  ...  \
# 0    3.0    4.0        10.0     1980.0  53.378933  14.625296  ...
# 1    2.0    8.0        10.0        NaN  53.442692  14.559690  ...
# 2    3.0    2.0         3.0        NaN  53.452222  14.553333  ...
# 3    3.0    2.0         3.0        NaN  53.435100  14.532900  ...
# 4    3.0    1.0         3.0        NaN  53.410278  14.503611  ...
#
#    pharmacyDistance    ownership  buildingMaterial  condition  \
# ...

# %%
apartments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18905 entries, 0 to 18904
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    18905 non-null  object
#  1   city                  18905 non-null  object
#  2   type                  14866 non-null  object
#  3   squareMeters          18905 non-null  float64
#  4   rooms                 18905 non-null  float64
#  5   floor                 15467 non-null  float64
#  6   floorCount            18643 non-null  float64
#  7   buildYear             15634 non-null  float64
#  8   latitude              18905 non-null  float64
#  9   longitude             18905 non-null  float64
#  10  centreDistance        18905 non-null  float64
#  11  poiCount              18905 non-null  float64
#  12  schoolDistance        18891 non-null  float64
#  13  clinicDistance        18817 non-null  float64
# ...

# %%
apartments.shape
# Out:
# (18905, 28)

# %%
apartments
# Out:
#                                      id       city          type  \
# 0      f8524536d4b09a0c8ccc0197ec9d7bde   szczecin  blockOfFlats
# 1      accbe77d4b360fea9735f138a50608dd   szczecin  blockOfFlats
# 2      8373aa373dbc3fe7ca3b7434166b8766   szczecin      tenement
# 3      0a68cd14c44ec5140143ece75d739535   szczecin      tenement
# 4      f66320e153c2441edc0fe293b54c8aeb   szczecin  blockOfFlats
# ...                                 ...        ...           ...
# 18900  ae88d7ea0a7a5fa0e9d287cfd78e5676  bydgoszcz  blockOfFlats
# 18901  6a4b30b5fcdee00bfe5bcc0da82df9b1  bydgoszcz  blockOfFlats
# 18902  1e7f4f1fdfea31eb84e071d697839632  bydgoszcz           NaN
# 18903  d971c4ed3aab9919bf203e96019a678e  bydgoszcz      tenement
# 18904  cd0241b70b79aaaf767a0dd3a7cfbb31  bydgoszcz           NaN
#
#        squareMeters  rooms  floor  floorCount  buildYear   latitude  \
# 0             63.00    3.0    4.0        10.0     1980.0  53.378933
# ...

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# ### Average prices in different cities

# %%
average_prices_by_city = apartments.groupby('city')['price'].mean()
print("Average prices of apartments in each city:")
for city, price in average_prices_by_city.items():
    print(f"{city}: {price:.2f}zł")
# Out:
# Average prices of apartments in each city:
# bialystok: 446369.58zł
# bydgoszcz: 409669.56zł
# czestochowa: 312733.55zł
# gdansk: 745904.59zł
# gdynia: 660882.48zł
# katowice: 449317.38zł
# krakow: 747664.17zł
# lodz: 411772.57zł
# lublin: 492458.13zł
# poznan: 574168.84zł
# radom: 331308.30zł
# rzeszow: 512647.33zł
# szczecin: 503863.82zł
# warszawa: 919840.33zł
# wroclaw: 667445.26zł

# %%
plt.bar(average_prices_by_city.index, average_prices_by_city)
plt.xlabel('City')
plt.ylabel('Average Price')
plt.title('Average Apartment Prices by City')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ### Average price for one square meter

# %%
apartments['price_for_square_meter'] = apartments['price']/apartments['squareMeters']
apartments.head()['price_for_square_meter']
# Out:
# 0     6587.301587
# 1    10999.861111
# 2     7737.606135
# 3     7305.936073
# 4    11500.000000
# Name: price_for_square_meter, dtype: float64

# %%
avg_price_for_square_meter = apartments.groupby('city')['price_for_square_meter'].mean()
avg_price_for_square_meter
# Out:
# city
# bialystok       8368.089344
# bydgoszcz       7506.943542
# czestochowa     5967.238577
# gdansk         13116.321878
# gdynia         10964.082744
# katowice        7678.158853
# krakow         13586.287233
# lodz            7730.721380
# lublin          8664.530677
# poznan          9892.107788
# radom           6342.590474
# rzeszow         9344.470397
# szczecin        8099.420467
# warszawa       15345.729993
# wroclaw        11587.809066
# Name: price_for_square_meter, dtype: float64

# %%
plt.bar(avg_price_for_square_meter.index, avg_price_for_square_meter)
plt.xlabel('City')
plt.ylabel('Average Price for square meter')
plt.title('Average prices for square meter')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ### Quartiles of prices in different cities

# %%
quartiles_by_city = apartments.groupby('city')['price'].quantile([0.25, 0.50, 0.75])
print("Quartiles by city:")
quartiles_by_city
# Out:
# Quartiles by city:
# city
# bialystok    0.25     370000.00
#              0.50     427000.00
#              0.75     524000.00
# bydgoszcz    0.25     289000.00
#              0.50     374000.00
#              0.75     499000.00
# czestochowa  0.25     249000.00
#              0.50     295000.00
#              0.75     353500.00
# gdansk       0.25     549000.00
#              0.50     670000.00
#              0.75     899000.00
# gdynia       0.25     469000.00
#              0.50     599000.00
#              0.75     779749.25
# katowice     0.25     309000.00
#              0.50     393000.00
#              0.75     550000.00
# krakow       0.25     550000.00
#              0.50     680000.00
#              0.75     880000.00
# lodz         0.25     295000.00
#              0.50     359000.00
#              0.75     480252.50
# lublin       0.25     385000.00
#              0.50     460000.00
#              0.75     585000.00
# poznan       0.25     439000.00
# ...

# %%
cities=list(apartments['city'].unique())
cities.sort()
for c in cities:

    plt.figure()
    plt.boxplot(apartments[apartments['city']==c]['price'])
    plt.title(c)
    plt.ylabel('Price')
    
    plt.show()

# %% [markdown]
# ### Quartiles by square meter

# %%
quartiles_by_square_meter = apartments.groupby('city')['price_for_square_meter'].quantile([0.25, 0.50, 0.75])
print("Quartiles by square meter:")
quartiles_by_square_meter
# Out:
# Quartiles by square meter:
# city
# bialystok    0.25     6925.705467
#              0.50     8150.578453
#              0.75     9520.176714
# bydgoszcz    0.25     6336.190831
#              0.50     7306.930693
#              0.75     8548.387097
# czestochowa  0.25     5103.638072
#              0.50     5948.553055
#              0.75     6556.764258
# gdansk       0.25    10494.253029
#              0.50    12098.581974
#              0.75    15000.172664
# gdynia       0.25     8997.673216
#              0.50    10583.409068
#              0.75    12535.670883
# katowice     0.25     6100.171233
#              0.50     7326.056004
#              0.75     8722.161092
# krakow       0.25    11014.451576
#              0.50    13001.322168
#              0.75    15400.000000
# lodz         0.25     6546.445160
#              0.50     7450.110865
#              0.75     8646.001955
# lublin       0.25     7556.186869
#              0.50     8491.295938
# ...

# %%
for c in cities:

    plt.figure()
    plt.boxplot(apartments[apartments['city']==c]['price_for_square_meter'])
    plt.title(c)
    plt.ylabel('Price for square meter')
    
    plt.show()

# %% [markdown]
# ### Square meter price vs. size of apartment

# %%
plt.scatter(apartments['squareMeters'], apartments['price_for_square_meter'],marker='.')
plt.xlabel('Size')
plt.ylabel('Price')
plt.title('Square meter price vs. size of apartment')
plt.grid()
plt.show()

# %% [markdown]
# ##### Question 1: How big apartment can we buy for 500 000 zł in different cities?

# %% [markdown]
# ##### Average size for 500 000zł

# %%
affordable_apartments = apartments[apartments['price'] <= 500000]
avg_affordable_apartments_by_city = affordable_apartments.groupby('city')['squareMeters'].mean()
avg_affordable_apartments_by_city
# Out:
# city
# bialystok      50.963564
# bydgoszcz      48.078397
# czestochowa    51.246121
# gdansk         38.749781
# gdynia         47.854536
# katowice       49.713706
# krakow         38.753881
# lodz           46.194826
# lublin         49.115235
# poznan         44.572365
# radom          50.928405
# rzeszow        50.169633
# szczecin       52.170660
# warszawa       35.040993
# wroclaw        39.193974
# Name: squareMeters, dtype: float64

# %%
plt.bar(avg_affordable_apartments_by_city.index, avg_affordable_apartments_by_city)
plt.xlabel('City')
plt.ylabel('Square Meters')
plt.title('Average size of apartment under 500 000zł in different cities')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ##### The biggest size for 500 000zł

# %%
max_affordable_apartments_by_city = affordable_apartments.groupby('city')['squareMeters'].max()
max_affordable_apartments_by_city
# Out:
# city
# bialystok       89.60
# bydgoszcz      122.48
# czestochowa    119.00
# gdansk          64.80
# gdynia          84.32
# katowice       109.37
# krakow          62.40
# lodz            96.00
# lublin          88.00
# poznan          84.90
# radom           92.39
# rzeszow         90.00
# szczecin       100.50
# warszawa        60.60
# wroclaw         61.40
# Name: squareMeters, dtype: float64

# %%
plt.bar(max_affordable_apartments_by_city.index, max_affordable_apartments_by_city)
plt.xlabel('City')
plt.ylabel('Square Meters')
plt.title('The biggest size of apartment under 500 000zł in different cities')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ##### Question 2: How expensive are apartments near the center in different cities?

# %%
close_apartments = apartments[apartments['centreDistance'] < 1]
avg_close_apartments_by_city = close_apartments.groupby('city')['price'].mean()
avg_close_apartments_by_city.round()
# Out:
# city
# bialystok       412129.0
# bydgoszcz       409435.0
# czestochowa     305754.0
# gdansk          902654.0
# gdynia          789832.0
# katowice        524711.0
# krakow          926091.0
# lodz            370645.0
# lublin          583966.0
# poznan          620972.0
# radom           348214.0
# rzeszow         512369.0
# szczecin        524662.0
# warszawa       1129689.0
# wroclaw         767557.0
# Name: price, dtype: float64

# %%
plt.bar(avg_close_apartments_by_city.index, avg_close_apartments_by_city)
plt.xlabel('City')
plt.ylabel('Price')
plt.title('Average price of apartments \n less than 1km from center')
plt.xticks(rotation=50)
plt.show()

# %%
quartiles_by_centre_distance = close_apartments.groupby('city')['price'].quantile([0.25, 0.50, 0.75])
print("Quartiles by centre distance:")
quartiles_by_centre_distance
# Out:
# Quartiles by centre distance:
# city
# bialystok    0.25     349000.00
#              0.50     399000.00
#              0.75     440000.00
# bydgoszcz    0.25     270000.00
#              0.50     388000.00
#              0.75     499000.00
# czestochowa  0.25     249000.00
#              0.50     290000.00
#              0.75     354750.00
# gdansk       0.25     678250.00
#              0.50     878400.00
#              0.75    1131000.00
# gdynia       0.25     595000.00
#              0.50     740000.00
#              0.75     970000.00
# katowice     0.25     359000.00
#              0.50     526500.00
#              0.75     695000.00
# krakow       0.25     649750.00
#              0.50     899000.00
#              0.75    1182000.00
# lodz         0.25     290742.50
#              0.50     350000.00
#              0.75     425000.00
# lublin       0.25     467500.00
#              0.50     580000.00
#              0.75     699500.00
# poznan       0.25     469000.00
# ...

# %%
for c in cities:

    plt.figure()
    plt.boxplot(close_apartments[close_apartments['city']==c]['price'])
    plt.title(c)
    plt.ylabel('Price for square meter')
    
    plt.show()

# %% [markdown]
# ##### Question 3: How expensive are flats from different years?

# %%
average_prices_by_year = apartments.groupby('buildYear')['price'].mean()
average_prices_by_year.round()
# Out:
# buildYear
# 1850.0     265000.0
# 1851.0    1850099.0
# 1852.0     510000.0
# 1854.0     724950.0
# 1855.0     460000.0
#             ...
# 2019.0     879347.0
# 2020.0     846474.0
# 2021.0     862831.0
# 2022.0     815153.0
# 2023.0     713786.0
# Name: price, Length: 155, dtype: float64

# %%
plt.plot(average_prices_by_year.index, average_prices_by_year.round())
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('Average price of apartments by year of build')
plt.grid()
plt.show()

# %% [markdown]
# ##### Question 4:  How expensive are one, two and three-rooms apartment in different cities?

# %%
one_room_apartments = apartments[apartments['rooms'] == 1]
two_rooms_apartments = apartments[apartments['rooms'] == 2]
three_rooms_apartments = apartments[apartments['rooms'] == 3]

avg_one_room_price = one_room_apartments.groupby('city')['price'].mean()
avg_two_rooms_price = two_rooms_apartments.groupby('city')['price'].mean()
avg_three_rooms_price = three_rooms_apartments.groupby('city')['price'].mean()

print("Average price for one room: \n", avg_one_room_price, "\n")
avg_one_room_price

print("Average price for two rooms: \n",avg_two_rooms_price, "\n")


print("Average price for three rooms: \n", avg_three_rooms_price, "\n")
# Out:
# Average price for one room:
#  city
# bialystok      336000.000000
# bydgoszcz      229023.809524
# czestochowa    203917.230769
# gdansk         440175.873134
# gdynia         386875.000000
# katowice       248125.222222
# krakow         468079.294118
# lodz           251338.217822
# lublin         301341.250000
# poznan         329923.568182
# radom          210175.882353
# rzeszow        356333.333333
# szczecin       284780.000000
# warszawa       516580.711974
# wroclaw        398003.518519
# Name: price, dtype: float64
#
# Average price for two rooms:
#  city
# bialystok      389897.905263
# bydgoszcz      327271.226519
# czestochowa    276453.629213
# gdansk         619871.881159
# gdynia         526651.171429
# katowice       356499.028708
# krakow         638024.653365
# lodz           334290.391778
# lublin         401348.212000
# poznan         479700.580175
# radom          291520.975309
# rzeszow        443653.985714
# szczecin       403183.754717
# ...

# %%
cities = avg_one_room_price.index
bar_width = 0.25

x = np.arange(len(cities))

fig, ax = plt.subplots(figsize=(12, 6))

ax.bar(x - bar_width, avg_one_room_price, width=bar_width, label='One-Room')
ax.bar(x, avg_two_rooms_price, width=bar_width, label='Two-Room')
ax.bar(x + bar_width, avg_three_rooms_price, width=bar_width, label='Three-Room')

ax.set_xticks(x)
ax.set_xticklabels(cities, rotation=45)
ax.set_xlabel('City')

ax.set_ylabel('Average Price')
ax.set_title('Average Apartment Prices by City and Room Type')

ax.legend()

plt.tight_layout()
plt.show()
